# %% [markdown]
# <a href="https://colab.research.google.com/github/Impactech/covid_xray_prediction/blob/master/covid_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Covid-19 predictor using posteroanterior (PA) chest X-ray images.**

# %% [markdown]
# The X-ray dataset is taken from - https://github.com/ieee8023/covid-chestxray-dataset.

# %% [markdown]
# I have been running this code on Google Colab environment using a GPU as a hardware accelerator. Since the notebook is using Resnet50 for transfer learning you will need a machine with an NVIDIA GPU otherwise the training might take ages

# %% [markdown]
# The folder structure I am using here to store the images is -
# <br>
# Covid/
# <br>
# ----| covid_positive
# <br>
# ----| covid_negative
# <br>
# ----| metadata.csv (This can be downloaded from the open source database)

# %% [markdown]
# Fast AI makes it extremely simple if you make a folder for each of your class and put all the respective images in that folder

# %% [markdown]
# **Disclaimer**: This notebook by no means is an accurate model to predict covid-19 or make any kind of diagnosis whatsoever. This is an ongoing experiment being done using opensource databases just as a POC. The model is not suitable for deployment.*

# %%
from fastai.vision import *
from fastai.widgets import *
import pandas as pd

# %% [markdown]
# Mount Google Drive with path to folders containing images. You need to change this path to point to the folder which contains the x-ray images

# %%
drive_path = 'drive/My Drive/FastAI/Covid/'

# %%
df = pd.read_csv(drive_path+'metadata.csv')

# %%
covid_positive = df['finding'] == 'COVID-19'

# %%
xrays = df['modality'] == 'X-ray'
CT = df['modality'] == 'CT'
PA = df['view'] == 'PA'
AP = df['view'] == 'AP'

# %% [markdown]
# I have cloned the image repository to my local machine. Since I am running this notebook on Colab I have to run a script on my local machine to upload the covid_postive and covid_negative images to my google drive.

# %% [markdown]
# PA_covid and PA_non_covid gives me the list of file names which are then uploaded to google drive

# %%
PA_covid = df[covid_positive & PA ]
PA_non_covid = df[PA & ~covid_positive]

# %%
#List files belonging to both the classes
covid_images = [files for files in PA_covid['filename']]
non_covid_images = [files for files in PA_non_covid['filename']]

# %%
path = Path(drive_path)

# %%
classes = ['covid_positive', 'covid_negative']

# %%
#sanity check images
for c in classes:
  verify_images(path/c)

# %%
#Split data into train and validation sets
data = ImageDataBunch.from_folder(path, train=".", test='test', valid_pct=0.25,
        ds_tfms=get_transforms(), bs=8, size=512, num_workers=4).normalize(imagenet_stats)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (149 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# covid_positive,covid_positive,covid_positive,covid_positive,covid_positive
# Path: drive/My Drive/FastAI/Covid;
#
# Valid: LabelList (49 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# covid_positive,covid_positive,covid_positive,covid_positive,covid_positive
# Path: drive/My Drive/FastAI/Covid;
#
# Test: LabelList (30 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: EmptyLabelList
# ,,,,
# Path: drive/My Drive/FastAI/Covid

# %%
#View data
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds), len(data.test_ds)
# Out:
# (['covid_negative', 'covid_positive'], 2, 159, 39, 30)

# %% [markdown]
# ## Training
# We are using a Resnet50 for transfer learning. Using fit one cycle for a few epochs and then using fastai's lrfinder to find an optimal range for our learning rate.
#
# We use precision and recall to measure the incidents of false positives and false negatives.

# %%
precision=Precision()
recall=Recall()
AUC=AUROC()

# %%
learn = cnn_learner(data, models.resnet50, metrics=(accuracy, precision, recall, AUC))

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.356049</td>
#       <td>1.467854</td>
#       <td>0.632653</td>
#       <td>0.642857</td>
#       <td>0.409091</td>
#       <td>0.816498</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(3)
learn.recorder.plot_losses()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.780940</td>
#       <td>0.582251</td>
#       <td>0.775510</td>
#       <td>0.789474</td>
#       <td>0.681818</td>
#       <td>0.917508</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.930111</td>
#       <td>1.348126</td>
#       <td>0.673469</td>
#       <td>0.800000</td>
#       <td>0.363636</td>
#       <td>0.771044</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.696235</td>
#       <td>0.713986</td>
#       <td>0.795918</td>
#       <td>0.875000</td>
#       <td>0.636364</td>
#       <td>0.883838</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='6', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [4/6 00:45<00:22]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.396417</td>
#       <td>#na#</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.603173</td>
#       <td>#na#</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.485660</td>
#       <td>#na#</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.475031</td>
#       <td>#na#</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='18', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       44.44% [8/18 00:06<00:08 0.8336]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, max_lr=slice(1e-6,3e-6))
learn.recorder.plot_losses()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.366462</td>
#       <td>0.797330</td>
#       <td>0.795918</td>
#       <td>0.875000</td>
#       <td>0.636364</td>
#       <td>0.883838</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.415618</td>
#       <td>0.675390</td>
#       <td>0.775510</td>
#       <td>0.823529</td>
#       <td>0.636364</td>
#       <td>0.885522</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.346195</td>
#       <td>0.851609</td>
#       <td>0.714286</td>
#       <td>0.900000</td>
#       <td>0.409091</td>
#       <td>0.882155</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.389726</td>
#       <td>0.791412</td>
#       <td>0.775510</td>
#       <td>0.923077</td>
#       <td>0.545455</td>
#       <td>0.888889</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.353896</td>
#       <td>0.615626</td>
#       <td>0.755102</td>
#       <td>0.750000</td>
#       <td>0.681818</td>
#       <td>0.893939</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='6', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [3/6 00:35<00:35]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.429253</td>
#       <td>#na#</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.397398</td>
#       <td>#na#</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.525626</td>
#       <td>#na#</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='18', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       83.33% [15/18 00:09<00:01 0.7310]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, max_lr=slice(5e-6,2e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.339669</td>
#       <td>0.670465</td>
#       <td>0.795918</td>
#       <td>0.875000</td>
#       <td>0.636364</td>
#       <td>0.892256</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.321450</td>
#       <td>0.623675</td>
#       <td>0.795918</td>
#       <td>0.875000</td>
#       <td>0.636364</td>
#       <td>0.909091</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.240033</td>
#       <td>0.544205</td>
#       <td>0.775510</td>
#       <td>0.866667</td>
#       <td>0.590909</td>
#       <td>0.909091</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.267077</td>
#       <td>0.527792</td>
#       <td>0.816327</td>
#       <td>0.882353</td>
#       <td>0.681818</td>
#       <td>0.917508</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.276160</td>
#       <td>0.577976</td>
#       <td>0.795918</td>
#       <td>0.875000</td>
#       <td>0.636364</td>
#       <td>0.925926</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.308620</td>
#       <td>0.470521</td>
#       <td>0.816327</td>
#       <td>0.882353</td>
#       <td>0.681818</td>
#       <td>0.930976</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.304911</td>
#       <td>0.457852</td>
#       <td>0.795918</td>
#       <td>0.833333</td>
#       <td>0.681818</td>
#       <td>0.927609</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.279543</td>
#       <td>0.532609</td>
#       <td>0.836735</td>
#       <td>0.937500</td>
#       <td>0.681818</td>
#       <td>0.924242</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.303569</td>
#       <td>0.448968</td>
#       <td>0.816327</td>
#       <td>0.782609</td>
#       <td>0.818182</td>
#       <td>0.919192</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.290932</td>
#       <td>0.543839</td>
#       <td>0.816327</td>
#       <td>0.882353</td>
#       <td>0.681818</td>
#       <td>0.927609</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='6', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [2/6 00:23<00:47]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.234567</td>
#       <td>#na#</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.169403</td>
#       <td>#na#</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='18', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       83.33% [15/18 00:09<00:01 0.3063]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(20, max_lr=slice(8e-5,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.322076</td>
#       <td>0.495412</td>
#       <td>0.816327</td>
#       <td>0.842105</td>
#       <td>0.727273</td>
#       <td>0.927609</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.279912</td>
#       <td>0.484062</td>
#       <td>0.836735</td>
#       <td>0.850000</td>
#       <td>0.772727</td>
#       <td>0.909091</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.291005</td>
#       <td>0.453530</td>
#       <td>0.857143</td>
#       <td>0.826087</td>
#       <td>0.863636</td>
#       <td>0.920875</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.297301</td>
#       <td>0.892714</td>
#       <td>0.734694</td>
#       <td>0.909091</td>
#       <td>0.454545</td>
#       <td>0.930976</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.343548</td>
#       <td>0.436237</td>
#       <td>0.836735</td>
#       <td>0.818182</td>
#       <td>0.818182</td>
#       <td>0.936027</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.370696</td>
#       <td>0.633898</td>
#       <td>0.877551</td>
#       <td>0.807692</td>
#       <td>0.954545</td>
#       <td>0.929293</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.373300</td>
#       <td>0.322910</td>
#       <td>0.897959</td>
#       <td>0.814815</td>
#       <td>1.000000</td>
#       <td>0.949495</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.332509</td>
#       <td>0.604464</td>
#       <td>0.775510</td>
#       <td>1.000000</td>
#       <td>0.500000</td>
#       <td>0.983165</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.315743</td>
#       <td>0.240321</td>
#       <td>0.877551</td>
#       <td>0.900000</td>
#       <td>0.818182</td>
#       <td>0.966330</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.369731</td>
#       <td>0.365187</td>
#       <td>0.877551</td>
#       <td>0.944444</td>
#       <td>0.772727</td>
#       <td>0.947811</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.289559</td>
#       <td>0.609716</td>
#       <td>0.857143</td>
#       <td>0.894737</td>
#       <td>0.772727</td>
#       <td>0.941077</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.268234</td>
#       <td>0.454224</td>
#       <td>0.857143</td>
#       <td>1.000000</td>
#       <td>0.681818</td>
#       <td>0.986532</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.247017</td>
#       <td>0.470392</td>
#       <td>0.857143</td>
#       <td>0.894737</td>
#       <td>0.772727</td>
#       <td>0.954545</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.209558</td>
#       <td>0.471399</td>
#       <td>0.857143</td>
#       <td>0.857143</td>
#       <td>0.818182</td>
#       <td>0.937710</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.220764</td>
#       <td>0.279114</td>
#       <td>0.897959</td>
#       <td>0.947368</td>
#       <td>0.818182</td>
#       <td>0.973064</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.226320</td>
#       <td>0.302877</td>
#       <td>0.836735</td>
#       <td>0.937500</td>
#       <td>0.681818</td>
#       <td>0.981481</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.198550</td>
#       <td>0.212525</td>
#       <td>0.897959</td>
#       <td>0.947368</td>
#       <td>0.818182</td>
#       <td>0.983165</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.200037</td>
#       <td>0.242637</td>
#       <td>0.877551</td>
#       <td>0.944444</td>
#       <td>0.772727</td>
#       <td>0.979798</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.185797</td>
#       <td>0.329568</td>
#       <td>0.857143</td>
#       <td>1.000000</td>
#       <td>0.681818</td>
#       <td>0.983165</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.204054</td>
#       <td>0.510584</td>
#       <td>0.857143</td>
#       <td>1.000000</td>
#       <td>0.681818</td>
#       <td>0.981481</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(4)

# %%
preds, y, losses = learn.get_preds(ds_type=DatasetType.Test, with_loss=True)
